# %%
import pandas as pd

# %%
citibike=pd.read_csv("JC-201807-citibike-tripdata.csv")

# %%
citibike.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
citibike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42268 entries, 0 to 42267
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42268 non-null  int64
#  1   starttime                42268 non-null  object
#  2   stoptime                 42268 non-null  object
#  3   start station id         42268 non-null  int64
#  4   start station name       42268 non-null  object
#  5   start station latitude   42268 non-null  float64
#  6   start station longitude  42268 non-null  float64
#  7   end station id           42268 non-null  int64
#  8   end station name         42268 non-null  object
#  9   end station latitude     42268 non-null  float64
#  10  end station longitude    42268 non-null  float64
#  11  bikeid                   42268 non-null  int64
#  12  usertype                 42268 non-null  object
#  13  birth year               42268 non-null  int64
# ...

# %%
# 3. Convert the 'tripduration' column to datetime datatype.
citibike["tripduration_datetime"] = pd.to_datetime(citibike["tripduration"], unit="m")

# %%
citibike.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0          1234  2018-07-01 02:08:39.8920  2018-07-01 02:29:14.4890
# 1          1041  2018-07-01 02:09:07.5180  2018-07-01 02:26:28.8720
# 2          2308  2018-07-01 02:14:45.7400  2018-07-01 02:53:14.5970
# 3           767  2018-07-01 02:25:12.4020  2018-07-01 02:38:00.0510
# 4           151  2018-07-01 04:07:44.0520  2018-07-01 04:10:15.8010
#
#    start station id start station name  start station latitude  \
# 0              3183     Exchange Place               40.716247
# 1              3183     Exchange Place               40.716247
# 2              3183     Exchange Place               40.716247
# 3              3183     Exchange Place               40.716247
# 4              3183     Exchange Place               40.716247
#
#    start station longitude  end station id end station name  \
# 0               -74.033459            3183   Exchange Place
# ...

# %%
citibike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42268 entries, 0 to 42267
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             42268 non-null  int64
#  1   starttime                42268 non-null  object
#  2   stoptime                 42268 non-null  object
#  3   start station id         42268 non-null  int64
#  4   start station name       42268 non-null  object
#  5   start station latitude   42268 non-null  float64
#  6   start station longitude  42268 non-null  float64
#  7   end station id           42268 non-null  int64
#  8   end station name         42268 non-null  object
#  9   end station latitude     42268 non-null  float64
#  10  end station longitude    42268 non-null  float64
#  11  bikeid                   42268 non-null  int64
#  12  usertype                 42268 non-null  object
#  13  birth year               42268 non-null  int64
# ...

# %%
citibike.to_csv("nyc_citi_bike_datetime.csv", index=False)
